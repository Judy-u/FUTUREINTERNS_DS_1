# %%
plt.figure(figsize=(6,4))
plt.hist(df['Overall_Rating'], bins=10)
plt.title('Overall Rating Distribution')
plt.xlabel('Overall Rating')
plt.ylabel('Number of Students')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
sns.countplot(x='Satisfaction', data=df)
plt.title('Student Satisfaction Distribution')
plt.xlabel('Satisfaction Level')
plt.ylabel('Number of Students')
plt.show()

# %%
def satisfaction_level(score):
    if score >= 7:
        return 'Satisfied'
    elif score >= 4:
        return 'Neutral'
    else:
        return 'Unsatisfied'

df['Satisfaction'] = df['Overall_Rating'].apply(satisfaction_level)

df[['Overall_Rating', 'Satisfaction']].head()
# Out:
#    Overall_Rating Satisfaction
# 0           5.000      Neutral
# 1           4.875      Neutral
# 2           4.375      Neutral
# 3           5.875      Neutral
# 4           7.500    Satisfied

# %%
rating_columns = df.columns.drop('Student ID')

df['Overall_Rating'] = df[rating_columns].mean(axis=1)

df[['Student ID', 'Overall_Rating']].head()
# Out:
#    Student ID  Overall_Rating
# 0         340           5.000
# 1         253           4.875
# 2         680           4.375
# 3         806           5.875
# 4         632           7.500

# %%
df.head()
# Out:
#    Student ID  Well versed with the subject  \
# 0         340                             5
# 1         253                             6
# 2         680                             7
# 3         806                             9
# 4         632                             8
#
#    Explains concepts in an understandable way  Use of presentations  \
# 0                                           2                     7
# 1                                           5                     8
# 2                                           7                     6
# 3                                           6                     7
# 4                                          10                     8
#
#    Degree of difficulty of assignments  Solves doubts willingly  \
# 0                                    6                        9
# 1                                    6                        2
# 2                                    5                        4
# ...

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
import pandas as pd

df = pd.read_csv('/content/student_feedback.csv')
df.head()
# Out:
#    Unnamed: 0  Student ID  Well versed with the subject  \
# 0           0         340                             5
# 1           1         253                             6
# 2           2         680                             7
# 3           3         806                             9
# 4           4         632                             8
#
#    Explains concepts in an understandable way  Use of presentations  \
# 0                                           2                     7
# 1                                           5                     8
# 2                                           7                     6
# 3                                           6                     7
# 4                                          10                     8
#
#    Degree of difficulty of assignments  Solves doubts willingly  \
# 0                                    6                        9
# 1                                    6                        2
# ...

# %%
import os
os.listdir('/content')
# Out:
# ['.config', 'student_feedback.csv', 'sample_data']

# %%
import os
os.listdir('/content')
# Out:
# ['.config', 'sample_data']

# %%
import pandas as pd

# Load the CSV file again
df = pd.read_csv('/content/student_feedback.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1852329164.py in <cell line: 0>()
#       2
#       3 # Load the CSV file again
# ----> 4 df = pd.read_csv('/content/student_feedback.csv')
#       5 df.head()
#
# ...

# %%
import pandas as pd

# Load the CSV file again
df = pd.read_csv('/content/student_feedback.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-865159181.py in <cell line: 0>()
#       2
#       3 # Load the CSV file again
# ----> 4 df = pd.read_csv('/content/student_feedback.csv')
#       5 df.head()
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2420516957.py in <cell line: 0>()
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt

# Drop Student ID and calculate average ratings
avg_ratings = df.drop(columns=['Student ID']).mean()

# Plot
plt.figure(figsize=(10,6))
avg_ratings.plot(kind='bar', color='skyblue')
plt.title('Average Ratings per Feedback Question')
plt.ylabel('Average Rating (1–5)')
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 5)
plt.tight_layout()
plt.show()

# %%
# Calculate the average rating for each feedback question (excluding Student ID)
df.drop(columns=['Student ID']).mean()
# Out:
# Well versed with the subject                            7.497502
# Explains concepts in an understandable way              6.081918
# Use of presentations                                    5.942058
# Degree of difficulty of assignments                     5.430569
# Solves doubts willingly                                 5.474525
# Structuring of the course                               5.636364
# Provides support for students going above and beyond    5.662338
# Course recommendation based on relevance                5.598402
# dtype: float64

# %%
df.isnull().sum()
# Out:
# Student ID                                              0
# Well versed with the subject                            0
# Explains concepts in an understandable way              0
# Use of presentations                                    0
# Degree of difficulty of assignments                     0
# Solves doubts willingly                                 0
# Structuring of the course                               0
# Provides support for students going above and beyond    0
# Course recommendation based on relevance                0
# dtype: int64

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('/content/student_feedback.csv')
df.head()
# Out:
#    Unnamed: 0  Student ID  Well versed with the subject  \
# 0           0         340                             5
# 1           1         253                             6
# 2           2         680                             7
# 3           3         806                             9
# 4           4         632                             8
#
#    Explains concepts in an understandable way  Use of presentations  \
# 0                                           2                     7
# 1                                           5                     8
# 2                                           7                     6
# 3                                           6                     7
# 4                                          10                     8
#
#    Degree of difficulty of assignments  Solves doubts willingly  \
# 0                                    6                        9
# 1                                    6                        2
# ...
